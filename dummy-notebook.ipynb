# %% [markdown]
# <a href="https://www.kaggle.com/code/kmljts/dummy-notebook?scriptVersionId=186272860" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
from tqdm.auto import tqdm
import time

pbar = tqdm(total=100, desc='Description')
for i in range(100):
    time.sleep(0.1)
    pbar.update(1)
pbar.close()
# Out:
# Description:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 2.5, 3, 4, 5, 6]
y = [2.4, 14.4, 384, 2000, 100_000, 10_000_000, 100_000_000] # kbps

fig, ax = plt.subplots()
ax.plot(x, y)

ax.set_yscale('log')
ax.set_xlabel('Generation (G)')
ax.set_ylabel('Max Speed (kbps)')
ax.set_title('Max Speed for Wireless Communication Technology')
ax.grid()
ax.axhline(1, c='k')
ax.axvline(1, c='k')

plt.show()

# %%
import numpy as np
from matplotlib.ticker import MaxNLocator

train_losses = np.random.rand(10)
val_losses = np.random.rand(10)
r2s = np.random.rand(10)
lrs = [10 ** -i for i in range(10)]
best_r2_epoch = 5

# %%
plt.figure(figsize=(8, 15))
plt.axis('off')

# ========== (1) ==========

plt.subplot(3, 1, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
if len(train_losses) < 20:
    plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.grid(True)
# plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.axvline(best_r2_epoch, color='cyan')
plt.legend(loc='best')
# plt.ylim(-0.05, 1)

# ========== (2) ==========

plt.subplot(3, 1, 2)
plt.plot(r2s, label='R2 Score')
plt.xlabel('Epoch')
plt.ylabel('Metrics')
if len(train_losses) < 20:
    plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.grid(True)
# plt.axhline(1, color='black')
plt.axvline(0, color='black')
plt.axvline(best_r2_epoch, color='cyan')
plt.legend(loc='best')

# ========== (3) ==========

plt.subplot(3, 1, 3)
plt.yscale('log')
plt.plot(lrs, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
if len(train_losses) < 20:
    plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.grid(True)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.axvline(best_r2_epoch, color='cyan')
plt.legend(loc='best')

plt.show()
# Out:
# /tmp/ipykernel_18/4178902089.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3, 1, 1)

# %%
# !python --version
# Out:
# Python 3.10.13

# %%
def sqrt(x):
    return x ** 0.5

def sqrt_est(x):
    sqrt = x ** 0.5
    pivot = np.round(sqrt)
    return pivot + (x - pivot ** 2) / (2 * pivot)

# %%
x = np.arange(0, 15, 0.001)
sqrs = x ** 2

y1 = sqrt(sqrs)
y2 = sqrt_est(sqrs)
diff = y2 - y1

plt.figure(figsize=(15, 6))
# plt.plot(x, y1, label='sqrt')
# plt.plot(x, y2, label='sqrt_est')
plt.plot(x, diff, label='diff')
plt.legend()
plt.grid()

plt.show()
# Out:
# /tmp/ipykernel_18/3333213815.py:7: RuntimeWarning: divide by zero encountered in divide
#   return pivot + (x - pivot ** 2) / (2 * pivot)
# /tmp/ipykernel_18/3333213815.py:7: RuntimeWarning: invalid value encountered in divide
#   return pivot + (x - pivot ** 2) / (2 * pivot)
